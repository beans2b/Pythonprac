# %%
# %%writefile class6.txt
# This is the class 6 review
# it might work or not
# Out:
# Writing class6.txt

# %%
# %%writefile -a class6.txt
# this will be added at the end of the file maybe
# Out:
# Appending to class6.txt

# %%
f = open("class6.txt","r",encoding="utf-8")
print(f.read())
f.close()
# Out:
# This is the class 6 review
# it might work or not
# this will be added at the end of the file maybe

# %%
f=open("class6.txt", "a")
f.write ("maybe is not\n a cool as wizard\n")
f.close()

f=open("class6.txt", "r")
print(f.read())
f.close()
# Out:
# This is the class 6 review
# it might work or not
# this will be added at the end of the file maybe
# maybe is not
#  a cool as wizard

# %%
with open("class6.txt", "r",encoding="utf-8") as f:
    first_line = f.readline()
print("First line:", first_line)
# Out:
# First line: This is the class 6 review

# %%
with open("class6.txt", "r",encoding="utf-8") as f:
    content = f.read()
print("This is the content of the text:\n", content)
# Out:
# This is the content of the text:
#  This is the class 6 review
# it might work or not
# this will be added at the end of the file maybe
# maybe is not
#  a cool as wizard

# %%
line1 = 3

with open("class6.txt","r", encoding="utf-8") as f:
    lines = f.readlines()
print(lines[line1].strip())
# Out:
# maybe is not

# %%
with open("class6.txt","r") as f:
    line0 = f.readline()
    line1 = f.readline()
    line2 = f.readline()
    line3 = f.readline()
print(line0.strip())
print(line1.strip())
print(line2.strip())
print(line3.strip())
# Out:
# This is the class 6 review
# it might work or not
# this will be added at the end of the file maybe
# maybe is not

# %%
with open("app_config.txt", "w") as f:
     f.write("This is the second test of class6,\n lets see if this works,\n otherwise i might be cooked\n")

with open("app_config.txt", "r") as f:
    content = f.read()
print("File content:\n", content)
# Out:
# File content:
#  This is the second test of class6,
#  lets see if this works,
#  otherwise i might be cooked

# %%
with open("app_config.txt", "w") as f:
     f.write("Username:system_admin\n Timeout_Seconds:300\n")

# %%
with open("app_config.txt", "r") as f:
    line_user = f.readline().strip().split(":")
    line_timeout = f.readline().strip().split(":")

line1 = line_user[1]
line2 = int(line_timeout[1])

print("Loaded Configuration:")
print(f"User ID: {line1}")
print(f"Session Timeout is set to {line2} seconds")
# Out:
# Loaded Configuration:
# User ID: system_admin
# Session Timeout is set to 300 seconds
