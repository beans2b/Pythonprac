# %%
print ("hello word!")
# Out:
# hello word!

# %%
print("hello world")
# Out:
# hello world

# %%
#done did that mate 
print('hello my man')
# Out:
# hello my man

# %%
print('clanker lover') #can u lend my a piece of paper my love?? //TODO
# Out:
# clanker lover

# %%
print("""hello
my name is
nazli""")
# Out:
# hello
# my name is
# nazli

# %%
print("hello", "brother"), print("hello")
# Out:
# hello brother
# hello
# (None, None)

# %%
print("hello"), print("myname is"), print("Whats ur name?")
# Out:
# hello
# myname is
# Whats ur name?
# (None, None, None)

# %%
print("bob\ndylan\njuan")
# Out:
# bob
# dylan
# juan

# %%
print("bim bom \tHbom bum")
# Out:
# bim bom 	Hbom bum

# %%
print("gooooool\\gooooooo")
# Out:
# gooooool\gooooooo

# %%
print("hello", end= "                     ")
print("hello")
# Out:
# hello                     hello

# %%
print("banana", "fresa", "granadilla")
# Out:
# banana fresa granadilla

# %%
print("banana", "fresa", "granadilla", sep="  |")
# Out:
# banana  |fresa  |granadilla

# %% [markdown]
# The error told me that there is an incomple input on the code written, in this case the "(" was not closed propertly, in order to fix it you need to add the propper ")" simbol at the end of the line of code in order to run it.
