# %%
2>3
# Out:
# False

# %%
bool1 = 2>3
print(bool1)
print(type(bool1))
# Out:
# False
# <class 'bool'>

# %%
penelope = False

if(penelope == True):
    print("penelope is true")
print ("penelope is false")
# Out:
# penelope is false

# %%
age = 35
if (age <= 30):
    print("u are still yn")
    print("please print what i say")
    age = 30
print(age)
# Out:
# 35

# %%
age = 25
if (age <= 30):
    print("u are still yn")
    print("please print what i say")
    age = 30
print(age)
# Out:
# u are still yn
# please print what i say
# 30

# %%
password = "PI399XW"
if len (password) < 8:
    print("'\"\'Invalid Password\"\''")
# Out:
# '"'Invalid Password"''

# %%
correct_password = "123XYZ"
password = "XYZ123"

if password == correct_password:
    print("the right one")
print("not the right one")
# Out:
# not the right one

# %%
""""ELIF"""
age = 10
if age > 100:
    print("og status")
elif age < 13:
    print("instagram older than bro")
elif age >=13 and age <= 25:
    print("ur a Yn ")
elif age >=26 and age <=44:
    print("unc status")

else:
    print ("ur dead fam")
# Out:
# instagram older than bro

# %%
user_age= 17
if user_age >= 18:
    print("you can vote")
else:
     print("you cant vote")
# Out:
# you cant vote

# %%
number = -7 
if number > 0:
    print ("the number is positive")
elif number < 0:
    print("the number is negative")
elif number == 0:
    print ("the number is 0")
# Out:
# the number is negative

# %%
purchase_amount= 120
is_member= True or False
discount = 0

if purchase_amount >= 100 and is_member:
    print("15 discount")
elif purchase_amount >= 50 and is_member:
print
