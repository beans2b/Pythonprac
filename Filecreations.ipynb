# %%
# %%writefile funnyfile.txt
# monkey poopie stinky
# Out:
# Writing funnyfile.txt

# %%
pwd
# Out:
# '/Users/p.madrid/MyMac/VS/MyPythonProjects/Session1_Basics'

# %%
# %%writefile -a funnyfile.txt
# WOOOOOOOOOOOOOOOOOOOooooooow
# Out:
# Appending to funnyfile.txt

# %%
with open ("funnyfile.txt", "w") as funny:
    funny.write("Noooooooooooooo, i was about to eat that banana\n")


with open ("funnyfile.txt", "r") as funny:
    content = funny.read()
print("file content:\n", content)
# Out:
# file content:
#  Noooooooooooooo, i was about to eat that banana

# %%
f=open("lizard.txt", "w")
f.write ("this lizard is coool\n")
f.close()

f=open("lizard.txt", "a")
f.write ("maybe is not a cool as wizard\n")
f.close()

f=open("lizard.txt", "r")
print(f.read())
f.close()
# Out:
# this lizard is coool
# maybe is not a cool as wizard
