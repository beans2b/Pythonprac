# %%
10*(7**6)-8%(48//10)
# Out:
# 1176490

# %%
"""label name + the equal sign gives you an assigned value to that number name"""
pizza_number = 6
pizza_price= 20
print(pizza_number)
# Out:
# 6

# %%
print(pizza_number*pizza_price/18)
# Out:
# 6.666666666666667
